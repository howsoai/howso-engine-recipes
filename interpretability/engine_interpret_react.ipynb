# %% [markdown]
# # Interpret Reactions with Howso Engine
#
# ## Overview
#
# This notebook provides an overview of applying Howso Engine to make predictions based on trained data and harnessing Howso Engine’s interpretability capabilities to understand why the predictions were made. Here, we demonstrate these capabilities on asteroid data. We build a Howso Engine Trainee to predict various information about different asteroids, understand the influential cases on the predictions, and understand the uncertainty of the predictions. This is a straightforward example of the power of Howso Engine to gain insights from data.

# %%
import os

import pandas as pd
import plotly.io as pio

from howso.engine import Trainee
from howso.utilities import infer_feature_attributes
from howso.visuals import plot_interpretable_prediction

pio.renderers.default = os.getenv("HOWSO_RECIPE_RENDERER", "notebook")

# %% [markdown]
# ## Step 1: Load the Data
#
# For this demonstration we will use a subset of a dataset containing measurements of various asteroids

# %%
dataset_path = "../data/asteroid.csv"
df_full = pd.read_csv(dataset_path, low_memory=False)
header = list(df_full)
df = df_full.truncate(after=5000)
df = df.where(df.notnull(), None)

df
# Out:
#                        full_name         a         e     G          i  \
# 0                        1 Ceres  2.769165  0.076009  0.12  10.594067
# 1                       2 Pallas  2.772466  0.230337  0.11  34.836234
# 2                         3 Juno  2.669150  0.256942  0.32  12.988919
# 3                        4 Vesta  2.361418  0.088721  0.32   7.141771
# 4                      5 Astraea  2.574249  0.191095   NaN   5.366988
# ...                          ...       ...       ...   ...        ...
# 4996        4997 Ksana (1986 TM)  2.871173  0.329960   NaN  32.732948
# 4997    4998 Kabashima (1986 VG)  3.007439  0.073460   NaN   9.904038
# 4998          4999 MPC (1987 CJ)  3.015442  0.040212   NaN  10.473593
# 4999         5000 IAU (1987 QN7)  2.537905  0.263911   NaN   6.265176
# 5000         5001 EMP (1987 SB1)  2.664662  0.170488   NaN  13.709129
#
#               om           w         q        ad     per_y  ...    rot_per  \
# 0      80.305532   73.597694  2.558684  2.979647  4.608202  ...   9.074170
# 1     173.080063  310.048857  2.133865  3.411067  4.616444  ...   7.813200
# 2     169.852760  248.138626  1.983332  3.354967  4.360814  ...   7.210000
# 3     103.810804  150.728541  2.151909  2.570926  3.628837  ...   5.342128
# 4     141.576604  358.687608  2.082324  3.066174  4.130323  ...  16.806000
# ...          ...         ...       ...       ...       ...  ...        ...
# 4996   10.726564   57.718579  1.923802  3.818544  4.865161  ...   3.434200
# 4997  352.226415  100.901739  2.786511  3.228367  5.215590  ...   6.138000
# 4998  155.933107  344.673442  2.894184  3.136701  5.236423  ...        NaN
# 4999  150.922214  232.797213  1.868123  3.207687  4.043163  ...        NaN
# 5000  169.905066  151.336692  2.210369  3.118955  4.349821  ...        NaN
#
#            GM     BV     UB  IR spec_B  spec_T  neo  pha      moid
# 0     62.6284  0.713  0.426 NaN      C       G    N    N  1.594780
# 1     14.3000  0.635  0.284 NaN      B       B    N    N  1.233240
# 2         NaN  0.824  0.433 NaN     Sk       S    N    N  1.034540
# 3     17.8000  0.782  0.492 NaN      V       V    N    N  1.139480
# 4         NaN  0.826  0.411 NaN      S       S    N    N  1.095890
# ...       ...    ...    ...  ..    ...     ...  ...  ...       ...
# 4996      NaN    NaN    NaN NaN      B    None    N    N  1.058150
# 4997      NaN    NaN    NaN NaN   None    None    N    N  1.824890
# 4998      NaN    NaN    NaN NaN   None    None    N    N  1.907750
# 4999      NaN    NaN    NaN NaN   None    None    N    N  0.878287
# 5000      NaN    NaN    NaN NaN   None    None    N    N  1.207720
#
# [5001 rows x 27 columns]

# %% [markdown]
# ## Step 2: Define and verify the feature attributes
#
# We use `infer_feature_attributes` to define feature attributes for our dataset, then print out the feature attributes to ensure they are correct.

# %%
features = infer_feature_attributes(df)

features
# Out:
# {'full_name': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'a': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.367879441, 'max': 20.085536923}},
#  'e': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.002478752, 'max': 1.0}},
#  'G': {'type': 'continuous',
#   'decimal_places': 2,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': -0.14, 'max': 1.0}},
#  'i': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.049787068, 'max': 148.413159103}},
#  'om': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.000335463, 'max': 403.428793493}},
#  'w': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.006737947, 'max': 403.428793493}},
#  'q': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.135335283, 'max': 20.085536923}},
#  'ad': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 1.0, 'max': 20.085536923}},
#  'per_y': {'type': 'continuous',
#   'decimal_places': 9,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.367879441, 'max': 54.598150033}},
#  'data_arc': {'type': 'continuous',
#   'decimal_places': 0,
#   'original_type': {'data_type': 'integer', 'size': 8},
#   'bounds': {'min': 2981.0, 'max': 162755.0, 'allow_null': False}},
#  'condition_code': {'type': 'continuous',
#   'decimal_places': 0,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.0, 'max': 3.0}},
#  'n_obs_used': {'type': 'continuous',
#   'decimal_places': 0,
#   'original_type': {'data_type': 'integer', 'size': 8},
#   'bounds': {'min': 20.0, 'max': 22026.0, 'allow_null': False}},
#  'H': {'type': 'continuous',
#   'decimal_places': 2,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 2.72, 'max': 54.6}},
#  'diameter': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'extent': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'albedo': {'type': 'continuous',
#   'decimal_places': 4,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.0067, 'max': 1.0}},
#  'rot_per': {'type': 'continuous',
#   'decimal_places': 6,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 1.0, 'max': 2980.957987}},
#  'GM': {'type': 'continuous',
#   'decimal_places': 6,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.000335, 'max': 148.413159}},
#  'BV': {'type': 'continuous',
#   'decimal_places': 3,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.368, 'max': 2.718}},
#  'UB': {'type': 'continuous',
#   'decimal_places': 3,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.05, 'max': 1.0}},
#  'IR': {'type': 'continuous',
#   'original_type': {'data_type': 'numeric', 'size': 8}},
#  'spec_B': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'spec_T': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'neo': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'pha': {'type': 'nominal', 'original_type': {'data_type': 'string'}},
#  'moid': {'type': 'continuous',
#   'decimal_places': 8,
#   'original_type': {'data_type': 'numeric', 'size': 8},
#   'bounds': {'min': 0.00247875, 'max': 20.08553692}}}

# %% [markdown]
# ## Step 3: Create and Train a Trainee
#
# As is the usual Howso Engine workflow: We create a Trainee, then train and analyze.

# %%
action_feature = ['moid']
context_features = features.get_names(without=['moid'])

trainee = Trainee(name='Engine - Interpretable Predictions Recipe', features=features, overwrite_existing=True)

trainee.train(df)

trainee.analyze()

# %% [markdown]
# ## Step 4: React
#
# First, we'll select one case to react to for demonstration purposes.
#
# This case is selected from the cases which were **_not_** trained, so the model does not know about this case in particular.

# %%
predict_index = 200001

df_full = df_full.astype(object)
df_full = df_full.where(df_full.notnull(), None) # convert NaN to None
case = df_full[predict_index:predict_index+1].iloc[0]  # grab a case that wasn't trained
context_values = case.iloc[0:26].tolist()
action_value = case.iloc[26]

# %%
df_full[predict_index:predict_index+1]
# Out:
#                       full_name         a         e     G         i  \
# 200001  200002 Hehe (2007 JZ43)  2.409757  0.158912  None  6.959368
#
#                 om           w         q        ad     per_y  ... rot_per  \
# 200001  116.592076  198.714295  2.026818  2.792696  3.740831  ...    None
#
#           GM    BV    UB    IR spec_B spec_T neo pha     moid
# 200001  None  None  None  None   None   None   N   N  1.01338
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Next, we react.
#
# When we call `react`, we include a request for certain `details`. Namely, `influential cases`. This will retrieve all of the cases which influenced the prediction and return them alongside the prediction itself. These can be used to interpret the prediction.

# %%
react = trainee.react(context_features=context_features,
                      action_features=action_feature,
                      contexts=[context_values],
                      details = {
                          'influential_cases': True,
                          'feature_residuals': True
                      })


print('Predicted action feature:')
display(react['action'])

local_residual = react['details']['feature_residuals'][0][action_feature[0]]
print('Local MAE of action feature:')
display(local_residual)

print('Computed explanation: ')
display(react['details'])
# Out:
# Predicted action feature:
#        moid
# 0  1.016037
# Local MAE of action feature:
# 0.042872775606068766
# Computed explanation:
# {'feature_residuals': [{'neo': 0.00019992003198720512,
#    'condition_code': 0.11740405850770019,
#    'BV': 0.03132739569013904,
#    'q': 0.044343748082575886,
#    'diameter': 1,
#    'e': 0.018007309661345873,
#    'spec_B': 0.8175381825962439,
#    'rot_per': 66.64109439441789,
#    'om': 93.36664456889585,
#    'pha': 0.017886261557721207,
#    'n_obs_used': 452.65580338907336,
#    'full_name': 1,
#    'UB': 0.03855388984514046,
#    'ad': 0.07156564751622302,
#    'extent': 1,
#    'G': 0.10133847426864025,
#    'spec_T': 0.5092503516918097,
#    'data_arc': 4881.456315377937,
#    'GM': 4.594496849575952,
#    'moid': 0.042872775606068766,
#    'w': 101.01908030333287,
#    'a': 0.034622158768711275,
#    'H': 0.6329794781634202,
#    'IR': [None, None],
#    'per_y': 0.08152782082382216,
#    'albedo': 0.0663070141104439,
#    'i': 2.9320753028882756}],
#  'influential_cases': [[{'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 1.946131274,
#     'diameter': '6.088',
#     'e': 0.183168802,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 193.9652682,
#     'pha': 'N',
#     'n_obs_used': 1166,
#     'full_name': '  3529 Dowling (1981 EQ19)',
#     'UB': None,
#     'ad': 2.818944493,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 24066,
#     'GM': None,
#     'moid': 0.947403,
#     'w': 184.6803071,
#     'a': 2.382537884,
#     'H': 14.7,
#     '.influence_weight': 0.1262033446871226,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.677629078,
#     '.session_training_index': 3528,
#     'albedo': 0.12,
#     'i': 2.762782159},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 2.082970523,
#     'diameter': None,
#     'e': 0.139376529,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 304.9144217,
#     'pha': 'N',
#     'n_obs_used': 1456,
#     'full_name': '  3135 Lauer (1981 EC9)',
#     'UB': None,
#     'ad': 2.757637693,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 14915,
#     'GM': None,
#     'moid': 1.10398,
#     'w': 118.4656864,
#     'a': 2.420304108,
#     'H': 13.8,
#     '.influence_weight': 0.12572363402912884,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.765417261,
#     '.session_training_index': 3134,
#     'albedo': None,
#     'i': 5.980839309},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 1.994213011,
#     'diameter': '7.569',
#     'e': 0.18147581,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 99.99372391,
#     'pha': 'N',
#     'n_obs_used': 1525,
#     'full_name': '  3984 Chacos (1984 SB6)',
#     'UB': None,
#     'ad': 2.878490903,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 17975,
#     'GM': None,
#     'moid': 0.993601,
#     'w': 263.5696408,
#     'a': 2.436351957,
#     'H': 14.4,
#     '.influence_weight': 0.12554661835708847,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.802929223,
#     '.session_training_index': 3983,
#     'albedo': 0.05,
#     'i': 2.938196995},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 1.93257344,
#     'diameter': '8.264',
#     'e': 0.183351018,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 125.460349,
#     'pha': 'N',
#     'n_obs_used': 1303,
#     'full_name': '  4270 Juanvictoria (1975 TJ6)',
#     'UB': None,
#     'ad': 2.800361964,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 15651,
#     'GM': None,
#     'moid': 0.963916,
#     'w': 321.1581146,
#     'a': 2.366467702,
#     'H': 14.1,
#     '.influence_weight': 0.12496074680009242,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.640483562,
#     '.session_training_index': 4269,
#     'albedo': 0.058,
#     'i': 12.15801335},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 2.05877313,
#     'diameter': None,
#     'e': 0.154852501,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 32.53274938,
#     'pha': 'N',
#     'n_obs_used': 1374,
#     'full_name': '  4549 Burkhardt (1276 T-2)',
#     'UB': None,
#     'ad': 2.813212249,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 23750,
#     'GM': None,
#     'moid': 1.07626,
#     'w': 52.20939042,
#     'a': 2.435992689,
#     'H': 14.2,
#     '.influence_weight': 0.12486229654507058,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.802088076,
#     '.session_training_index': 4548,
#     'albedo': None,
#     'i': 2.82800126},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 2.031213919,
#     'diameter': None,
#     'e': 0.15333752,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 111.4133909,
#     'pha': 'N',
#     'n_obs_used': 2229,
#     'full_name': '  4579 Puccini (1989 AT6)',
#     'UB': None,
#     'ad': 2.766952921,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 15040,
#     'GM': None,
#     'moid': 1.01725,
#     'w': 139.8868548,
#     'a': 2.39908342,
#     'H': 13.8,
#     '.influence_weight': 0.12453843458704493,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.716004457,
#     '.session_training_index': 4578,
#     'albedo': None,
#     'i': 2.213643473},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 2.009201985,
#     'diameter': None,
#     'e': 0.135256466,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 121.2566487,
#     'pha': 'N',
#     'n_obs_used': 2124,
#     'full_name': '  4444 Escher (1985 SA)',
#     'UB': None,
#     'ad': 2.637729516,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 12336,
#     'GM': None,
#     'moid': 0.993099,
#     'w': 181.9089102,
#     'a': 2.32346575,
#     'H': 13.7,
#     '.influence_weight': 0.12418118673206265,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.541706878,
#     '.session_training_index': 4443,
#     'albedo': None,
#     'i': 7.39179449},
#    {'neo': 'N',
#     'condition_code': 0,
#     'BV': None,
#     'q': 2.025190037,
#     'diameter': '9.329',
#     'e': 0.16727836,
#     'spec_B': None,
#     'rot_per': None,
#     'om': 50.31458215,
#     'pha': 'N',
#     'n_obs_used': 1599,
#     'full_name': '  4480 Nikitibotania (1985 QM4)',
#     'UB': None,
#     'ad': 2.838836405,
#     'extent': None,
#     'G': None,
#     'spec_T': None,
#     'data_arc': 16366,
#     'GM': None,
#     'moid': 1.03308,
#     'w': 351.0376299,
#     'a': 2.432013221,
#     'H': 14,
#     '.influence_weight': 0.12398373826238955,
#     'IR': None,
#     '.session': '4c127c68-7575-4073-a231-d9096bb7c2b3',
#     'per_y': 3.792775173,
#     '.session_training_index': 4479,
#     'albedo': 0.068,
#     'i': 3.393788898}]],
#  'action_features': ['moid']}

# %% [markdown]
# ## Step 5: View the influential cases
#
# The predicted case and the influential cases can be viewed side-by-side.

# %%
pd.options.display.max_columns = None #show all features

most_similar_df = pd.DataFrame(react['details']['influential_cases'][0])
most_similar_df = most_similar_df.drop(['.session_training_index', '.session'], axis=1)

display(df_full.iloc[predict_index:predict_index+1])
display(most_similar_df[header])
# Out:
#                       full_name         a         e     G         i  \
# 200001  200002 Hehe (2007 JZ43)  2.409757  0.158912  None  6.959368
#
#                 om           w         q        ad     per_y data_arc  \
# 200001  116.592076  198.714295  2.026818  2.792696  3.740831     6472
#
#        condition_code n_obs_used     H diameter extent albedo rot_per    GM  \
# 200001            0.0        226  16.7     None   None   None    None  None
#
#           BV    UB    IR spec_B spec_T neo pha     moid
# 200001  None  None  None   None   None   N   N  1.01338
#                          full_name         a         e     G          i  \
# 0         3529 Dowling (1981 EQ19)  2.382538  0.183169  None   2.762782
# 1            3135 Lauer (1981 EC9)  2.420304  0.139377  None   5.980839
# 2           3984 Chacos (1984 SB6)  2.436352  0.181476  None   2.938197
# 3     4270 Juanvictoria (1975 TJ6)  2.366468  0.183351  None  12.158013
# 4        4549 Burkhardt (1276 T-2)  2.435993  0.154853  None   2.828001
# 5          4579 Puccini (1989 AT6)  2.399083  0.153338  None   2.213643
# 6            4444 Escher (1985 SA)  2.323466  0.135256  None   7.391794
# 7    4480 Nikitibotania (1985 QM4)  2.432013  0.167278  None   3.393789
#
#            om           w         q        ad     per_y  data_arc  \
# 0  193.965268  184.680307  1.946131  2.818944  3.677629     24066
# 1  304.914422  118.465686  2.082971  2.757638  3.765417     14915
# 2   99.993724  263.569641  1.994213  2.878491  3.802929     17975
# 3  125.460349  321.158115  1.932573  2.800362  3.640484     15651
# 4   32.532749   52.209390  2.058773  2.813212  3.802088     23750
# 5  111.413391  139.886855  2.031214  2.766953  3.716004     15040
# 6  121.256649  181.908910  2.009202  2.637730  3.541707     12336
# 7   50.314582  351.037630  2.025190  2.838836  3.792775     16366
#
#    condition_code  n_obs_used     H diameter extent  albedo rot_per    GM  \
# 0               0        1166  14.7    6.088   None   0.120    None  None
# 1               0        1456  13.8     None   None     NaN    None  None
# 2               0        1525  14.4    7.569   None   0.050    None  None
# 3               0        1303  14.1    8.264   None   0.058    None  None
# 4               0        1374  14.2     None   None     NaN    None  None
# 5               0        2229  13.8     None   None     NaN    None  None
# 6               0        2124  13.7     None   None     NaN    None  None
# 7               0        1599  14.0    9.329   None   0.068    None  None
#
#      BV    UB    IR spec_B spec_T neo pha      moid
# 0  None  None  None   None   None   N   N  0.947403
# 1  None  None  None   None   None   N   N  1.103980
# 2  None  None  None   None   None   N   N  0.993601
# 3  None  None  None   None   None   N   N  0.963916
# 4  None  None  None   None   None   N   N  1.076260
# 5  None  None  None   None   None   N   N  1.017250
# 6  None  None  None   None   None   N   N  0.993099
# 7  None  None  None   None   None   N   N  1.033080

# %% [markdown]
# ## Step 6: Intepret
#
# We react several more times generatively to determine a range of possible predicted values.
#
# These will be used to visualize the distribution of the predicted feature compared to the held-out case, the predicted case, and the influential cases. This visualization is one of many techniques which could be used to interpret the results.

# %%
gen_reacts = list()
for i in range(0,100):
    result =  trainee.react(context_features=context_features,
                            action_features=action_feature,
                            contexts=[context_values],
                            desired_conviction = 5000)
    gen_reacts.append(result['action'].loc[0, 'moid'])

# %%
plot_interpretable_prediction(
    react,
    actual_value=action_value,
    generative_reacts=gen_reacts,
    residual=local_residual,
)
# Out:
# /home/runner/.local/lib/python3.11/site-packages/kaleido/scopes/base.py:188: DeprecationWarning:
#
# setDaemon() is deprecated, set the daemon attribute instead

# %% [markdown]
# This visualization show us the probability density of the action feature value given the context as well as the values of the influential cases and their corresponding influence weights. All of this information is at the core of how the Howso Engine makes its predictions, which should elucidate the information that is used when the Trainee makes a prediction.

# %% [markdown]
# ## Step 7: Use a non-visual interpretation
#
# Howso Engine provides a number of tools for interpreting reacts. Below, we compare the MDA (Mean Decrease in Accuracy) for the predicted case and the original case. Inspecting the difference between these MDA values can indicate to the user how much the local model changes when the action feature and value become part of the context that determines the influential cases.
#
# > Reminder: The "local model" is the region of the data surrounding a prediction made up by its influential cases. In contrast, the entire dataset can be referred to as the "global model".

# %%
react = trainee.react(context_features=context_features,
                      action_features=action_feature,
                      contexts=[context_values],
                      details = {
                         'feature_mda': True,
                         'robust_influences': True
                      })

loc_mda = react['details']['feature_mda']

mda_dict = dict(sorted(loc_mda[0].items(), key=lambda item: item[1], reverse=True))
mda_df = pd.DataFrame(columns=['original', 'predicted'])
mda_df['predicted'] = mda_dict.values()
mda_df.index = mda_dict.keys()

react2 = trainee.react(context_features=context_features,
                       action_features=action_feature,
                       actions=[[action_value]],  # specify "actual" actual value
                       contexts=[context_values],
                       details = {
                           'feature_mda_ex_post': True,
                           'robust_influences': True
                       })

loc_mda_post_facto = react2['details']['feature_mda_ex_post']
mda_dict = dict(sorted(loc_mda_post_facto[0].items(), key=lambda item: item[1], reverse=True))
mda_df['original'] = mda_dict.values()

display(mda_df)
# Out:
#                 original  predicted
# q               0.020752   0.031895
# per_y           0.013732   0.016487
# a               0.013635   0.016269
# rot_per         0.012548   0.013777
# i               0.010587   0.012503
# BV              0.008814   0.011702
# H               0.006946   0.011544
# condition_code  0.006686   0.007448
# G               0.006313   0.006531
# w               0.003756   0.006330
# IR              0.003511   0.006005
# e               0.003490   0.005971
# spec_T          0.003261   0.005457
# GM              0.002725   0.004648
# full_name       0.002191   0.004370
# diameter        0.001368   0.004189
# spec_B         -0.001003   0.001833
# extent         -0.001474  -0.000465
# neo            -0.001946  -0.000919
# om             -0.002077  -0.001309
# UB             -0.002415  -0.001499
# data_arc       -0.002654  -0.001524
# ad             -0.003404  -0.001891
# pha            -0.003448  -0.002318
# n_obs_used     -0.006280  -0.004940
# albedo         -0.008019  -0.007573

# %% [markdown]
# # Conclusion
#
# This recipe further demonstrates the interpretability tools available to users alongside their predictions with the `react` call. When using a series of generative `react`'s alongside the discriminative `react` used for the prediction, users can visualize the probability distribution of the action feature given the specific context. Additionally, users can see the exact cases from the training data that were used to make the prediction.
#
# This interpretability is crucial for many machine learning use-cases whether it be safety-critical applicaitons or any other model that can directly impact the lives of those affected by its decisions. Without interpretability, users must blindly accept model predictions which can often lead to incorrect predictions severely impacting people in often disproportional ways. The ability to maintain accuracy while providing full interpretability is at the core of the Howso Engine's design.
